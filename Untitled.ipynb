# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rand = np.random.randint(1,7,1000)
plt.hist(rand)
# Out:
# (array([172.,   0., 157.,   0., 169.,   0., 151.,   0., 165., 186.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <a list of 10 Patch objects>)

# %%
rand = np.random.randint(1,7,5000)
plt.hist(rand)
# Out:
# (array([838.,   0., 810.,   0., 837.,   0., 841.,   0., 813., 861.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <a list of 10 Patch objects>)

# %%
rand = np.random.randint(1,7,50000)
plt.hist(rand)
# Out:
# (array([8313.,    0., 8305.,    0., 8249.,    0., 8395.,    0., 8368.,
#         8370.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <a list of 10 Patch objects>)

# %%
rand = np.random.randint(1,7,50)
plt.hist(rand)
# Out:
# (array([13.,  0.,  8.,  0.,  6.,  0.,  7.,  0.,  6., 10.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <a list of 10 Patch objects>)

# %%
rand = np.random.randint(1,7,100)
plt.hist(rand)
# Out:
# (array([19.,  0., 14.,  0., 20.,  0., 14.,  0., 20., 13.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <a list of 10 Patch objects>)

# %%
rand = np.random.randint(1,7,20)
plt.hist(rand)
# Out:
# (array([4., 0., 2., 0., 6., 0., 1., 0., 6., 1.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <a list of 10 Patch objects>)

# %%
rand = np.random.randint(1,7,500000)
plt.hist(rand)
# Out:
# (array([83252.,     0., 83545.,     0., 83597.,     0., 83195.,     0.,
#         83501., 82910.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <a list of 10 Patch objects>)

# %%
rand = np.random.randint(1,7,1000)

# %%
tot6=[]
for i in range(2,10000):
    rand = np.random.randint(1,7,i)
    tot6.append((rand==6).sum())

# %%
plt.figure(figsize=(15,5))
plt.plot(tot6[:100])
